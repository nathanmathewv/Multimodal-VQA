# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Replace with your image file path
image_path = r"Dataset/small/00/00a0a32d.jpg"

img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis("off")
plt.show()
